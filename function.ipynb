# %%
name=input("Enter the name:")
print("welcome", name)
# Out:
# Enter the name: rishitha
# welcome rishitha

# %%
p="Python"
print(p[::-1])
# Out:
# nohtyP

# %%
p="Rishithakashety"
print(p[::-3])
# Out:
# yhkts

# %%
name="kavita"
def greet():
    print("Hello",name)
greet()
# Out:
# Hello kavita

# %%
name="rishitha"
def greet():
    print("Hello",name)
greet()
# Out:
# Hello rishitha

# %%
name="Rishitha"
def greet():
    print("congrats",name)
greet()
# Out:
# congrats Rishitha

# %%
def add(a,b):
    return a+b
print(add(10,20))
# Out:
# 30

# %%
def add(a,b,c=0):
    return a+b+c
print(add(10,20))
print(add(10,20,30))
# Out:
# 30
# 60

# %%
def add (a,b,c=0):
    return a+b-c
print(add(10,20))
print(add(10,20,40))
# Out:
# 30
# -10

# %%
def add (a,b,c=0):
    return a*b*c
print(add(20,50))
print(add(20,50,40))
# Out:
# 0
# 40000

# %%
def add (*numbers):
    print(sum(numbers))
add(10,20)
add(10,20,30,)
add(10,20,30,40,)
add(10,20,30,40,50,)
# Out:
# 30
# 60
# 100
# 150

# %%
def student(*marks):
    print(sum(marks))
student(55,78,78,54,)
student(578,879,809,879)
# Out:
# 265
# 3145

# %%
print(10+20)
print("kavitha" + "yadav")
# Out:
# 30
# kavithayadav

# %%
print(40+80)
print("rishitha" + "patel")
# Out:
# 120
# rishithapatel
