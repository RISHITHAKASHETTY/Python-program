# %%
name = ["paint","brush","color"]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
# Out:
# paint
# brush
# color

# %%
name = [7,9,5]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
# Out:
# 7
# 9
# 5
