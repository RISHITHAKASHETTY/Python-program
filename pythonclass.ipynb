# %%
name="rishitha"
print(name)
# Out:
# rishitha

# %%
city="Jagtial"
print(city[1])
# Out:
# a

# %%
city="Dharamapuri"
print(city[0])
# Out:
# D

# %%
city="Dharamapuri"
print(city[-4])
# Out:
# p

# %%
name="rishitha"
print(name[1:6])
# Out:
# ishit

# %%
name="rishitha"
print(len(name))
# Out:
# 8

# %%
first="rishitha"
second="patel"
print(first+""+second)
# Out:
# rishithapatel

# %%
print("Hello" * 3)
# Out:
# HelloHelloHello

# %%
print("rishitha" * 10)
# Out:
# rishitharishitharishitharishitharishitharishitharishitharishitharishitharishitha

# %%
name="rishitha"
print(name.upper())
# Out:
# RISHITHA

# %%
name="RISHITHA"
print(name.lower())
# Out:
# rishitha

# %%
name="kashetty rishitha"
print(name.upper())
# Out:
# KASHETTY RISHITHA

# %%
name="KASHETTY RISHITHA"
print(name.lower())
# Out:
# kashetty rishitha

# %%
s="I like Java"
print(s.replace("Java" , "Python"))
# Out:
# I like Python

# %%
s="anything something"
print(s.find("something"))
# Out:
# 9

# %%
name=input("Enter the name :")
print("welcome", name)
